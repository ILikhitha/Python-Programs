# %% [markdown]
# <a href="https://colab.research.google.com/github/ILikhitha/Python-Programs/blob/main/Matplotlib_plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import matplolib

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.2.2

# %% [markdown]
# ## Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,25])
ypoints = np.array([0,300])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,15])
ypoints = np.array([3,30])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,20])
ypoints = np.array([3,30])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,3,6,9])
ypoints = np.array([3,9,2,15])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4,9,1,6,8])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4,9,1,15])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
...
plt.plot(ypoints, marker = '*')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'o')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '.')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = ',')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'x')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'X')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '+')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'P')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 's')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'D')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'd')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'p')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'H')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'h')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'v')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '^')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '<')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '>')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '1')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '2')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '3')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '4')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '|')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = '_')
...
# Out:
# Ellipsis

# %%
# Format Strings fmt
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,12])

plt.plot(ypoints, 'o:b')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'o-')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-2bd9775dd876> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'o:')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-7971dc1082a2> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'o--')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-a5004e044796> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'o-.')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-f6bcc77d4ef6> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %% [markdown]
# ## Color reference

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'or')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-dcac75353461> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'og')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-71fafda0c257> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'ob')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-76067ce6edde> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'oc')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-838f60c4daec> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'om')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-5a7e5a80d963> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'oy')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-687093802990> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'ok')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-c9d1839fc0b6> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, 'ow')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-11e2353a93c2> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'm')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'k', mfc = 'm')
plt.show()

# %%
...
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
...
# Out:
# Ellipsis

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %%
plt.plot(ypoints, ls = ':')

# %%
plt.plot(ypoints, ls = '--')

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, ls = '-')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-ae4626c6c4fd> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, ls = ':')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-80bc8e017698> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, ls = '--')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-c10f7cb5e2d9> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, ls = '-.')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-a7e671d6eed1> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,15])

plt.plot(ypoints, ls = ''or'')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-48537fb53cba> in <module>()
#      11 plt.show()
#      12
# ---> 13 plt.savefig(sys.stdout.buffer)
#      14 sys.stdout.flush()
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'y')
plt.show()

# %%
...
plt.plot(ypoints, c = '#4CAF50')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, c = 'hotpink')
...
# Out:
# Ellipsis

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2,9,1,10])

plt.plot(ypoints, linewidth = '25')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([2,9,1,10])
y2 = np.array([6,2,9,11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3,4])
y1 = np.array([3, 8, 1, 10,15])
x2 = np.array([0, 1, 2, 3,5])
y2 = np.array([6, 2, 7, 11,14])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
# Create Labels for a Plot
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Stars Analysis")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Stars Analysis", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Stars Analysis", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %%
# Matplotlib Adding Grid Lines
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Stars Analysis")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Stars Analysis")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Stars Analysis")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Stars Analysis")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'orange', linestyle = '--', linewidth = 0.75)

plt.show()

# %% [markdown]
# ## Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 11])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 11])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
# Title
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 11])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Stars")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Shooting rate")

plt.show()

# %%
# Supertitle
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Stars")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Shooting rate")

plt.suptitle("Series")
plt.show()

# %% [markdown]
# ## Scatters

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6,8,10])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86,90,92])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6,9])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86,90])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12,10])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85,88])
plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# ## Plotting bars

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = ["Cherry", "Litchi"]
y = [400, 350]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "blue")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 11])

plt.bar(x, y, width = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.5)
plt.show()

# %% [markdown]
# ## Histograms

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [160.79032617 170.07259996 153.55935302 161.86767822 168.56957457
#  159.9616217  146.72017174 178.36160209 168.06286586 150.45863113
#  158.90340622 167.25990514 175.54072285 163.26962683 185.9125142
#  156.47745493 175.29201522 169.52307005 171.56561531 161.53295399
#  173.3244113  172.77959785 169.67553114 170.88955909 183.73074874
#  182.23059146 161.89878069 173.51001747 153.30946257 166.14519227
#  161.92569487 168.13040696 175.378437   153.68882301 154.48857747
#  170.49761221 187.09551322 178.17236207 161.9010392  167.60634848
#  182.88370811 178.16285317 166.60195845 172.08698613 169.31727422
#  179.34780217 162.90396166 183.66425854 172.91002342 172.30493658
#  175.26963541 181.81453099 179.59726128 155.68342793 166.62269573
#  170.74883937 169.00267269 176.31975922 160.68964804 165.21832624
#  167.77531541 169.91767296 169.97503923 172.14484827 161.93561387
#  174.01588721 184.35085917 166.19514197 179.34007141 162.85461071
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 255)

plt.hist(x)
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Mangoes", "Grapes", "Cherries", "Kiwis"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Mangoes", "Grapes", "Cherries", "Kiwis"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Mangoes", "Grapes", "Cherries", "Kiwis"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Mangoes", "Grapes", "Cherries", "Kiwis"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Mangoes", "Grapes", "Cherries", "Kiwis"]
mycolors = ["r", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#Legend
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Mangoes", "Grapes", "Cherries", "Kiwis"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Mangoes", "Grapes", "Cherries", "Kiwis"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Star Fruits:")
plt.show()
